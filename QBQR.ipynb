# %% [markdown]
# # Basket Trading model with LSTM deep neural net performing pointwise ranking of stocks within industry sectors

# %%
transaction_cost = 0.0005     # brokerage fee of 5 bps
safety_margin = 0.20          # safety margin of 20%
risk_free = 0.006             # 1-year risk-free rate 0.6%

# %%
import pandas as pd
import numpy as np
import scipy as sc
import math as mt

from keras.models import Sequential
from keras.layers import Dense, Activation, LSTM

# %% [markdown]
# ######

# %% [markdown]
# # Reading and transforming data

# %%
Sectors = pd.read_csv('https://raw.githubusercontent.com/QBQR/Trial-assignment/master/Data/sectors.csv')
SPX_Mask = pd.read_csv('https://raw.githubusercontent.com/QBQR/Trial-assignment/master/Data/in_spx_mask.csv')

# %%
def get_features(n_lags, Stock, Mask):
    
    Quotes = pd.read_csv('https://raw.githubusercontent.com/QBQR/Trial-assignment/master/Data/Market%20data/' + Stock + '.csv')
    Features = pd.DataFrame(Quotes['Date_Time'])
    Features['Date'] = Quotes['Date_Time'].apply(lambda x: x.split(' ')[0])
    
    # Stock returns up to n-th lag
    Features['r_0'] = np.log(Quotes['Close']) - np.log(Quotes['Open'])
    for i in range(1, n_lags+1):
        Features['r_'+str(i)] = Features['r_0'].shift(i)
    Features['r_f'] = Features['r_0'].shift(-1)
    
    # Volatility range
    Features['high_low'] = 2*(Quotes['High'] - Quotes['Low'])/(Quotes['Open'] + Quotes['Close'])
    
    # Trading volume (log-difference)
    Features['d_volume'] = np.log(1+Quotes['Volume']) - np.log(1+Quotes['Volume'].shift(1))
    
    # Mask ???
    if (len(set(Mask[Mask.columns[1]])) > 1):
        Features = Features.merge(Mask.rename(columns={Mask.columns[1]: 'mask'}), how='left', on='Date')
        Features['mask'] = Features['mask'].astype(float)
    
    # EPS yield and EPS surprise
    try:
        EPS = pd.read_csv('https://raw.githubusercontent.com/QBQR/Trial-assignment/master/Data/EPS%20data/' + Stock + '.csv')
        EPS_ = pd.DataFrame(EPS['Date'])
        EPS_['EPS_annual'] = EPS['Earnings EPS'].rolling(4).sum()
        EPS_['EPS_surprise'] = EPS['Earnings EPS']/EPS['Estimate EPS']-1
        EPS_['EPS_comp'] = EPS['Earnings EPS']/EPS['Comparable EPS']-1
        Features = Features.merge(EPS_, how='left', on='Date')
        Features['EPS_annual'] = Features['EPS_annual'].fillna(method='ffill')
        Features['EPS_yield'] = 2*Features['EPS_annual']/(Quotes['Open'] + Quotes['Close'])
        Features['EPS_surprise'].fillna(0, inplace = True)
        Features['EPS_comp'].fillna(0, inplace = True)
        del Features['EPS_annual']
    except:
        pass

    # Dividend yield
    try:
        DIV = pd.read_csv('https://raw.githubusercontent.com/QBQR/Trial-assignment/master/Data/DIV%20data/' + Stock + '.csv')
        Features = Features.merge(DIV.groupby('Date').agg({'Dividend Amount': np.mean}).reset_index(), how='left', on='Date')
        Features['Dividend Amount'].fillna(0, inplace = True)
        Features['div_yield'] = 2*Features['Dividend Amount']/(Quotes['Open'] + Quotes['Close'])
        del Features['Dividend Amount']
    except: 
        pass
    
    return Features.dropna()

# %% [markdown]
# ######

# %% [markdown]
# # Defining predictor of the next period return

# %%
n_lags = 49
layers_num = 8

# %%
def make_model(n_features, layers_num):
    model = Sequential()
    model.add(LSTM(layers_num, input_shape=(1, n_features)))
    model.add(Dense(layers_num))
    model.add(Activation('relu'))
    model.add(Dense(layers_num))
    model.add(Activation('relu'))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %% [markdown]
# ######

# %% [markdown]
# # Training predictor for each stock

# %%
Cut_off_date = '2016-01-01'
batch_size = 3250
epoch_size = 100
test_dict = np.load('QBQR_dict.npy').item()

for row in Sectors.iterrows():
    
    # reading data
    index = row[0]
    Stock = row[1]['Ticker']
    print ('Training model ' + str(index + 1) + ' out of ' + str(len(Sectors.index)) + '. Ticker: ' + Stock)

    if (Stock in test_dict.keys()):
        continue
    
    Mask = SPX_Mask[['Date', Stock]]   
    Features = get_features(n_lags, Stock, Mask)
    
    # splitting train / test sets
    Train_set = Features[Features['Date'] < Cut_off_date]
    Test_set = Features[Features['Date'] >= Cut_off_date]

    trainY = Train_set['r_f'].values
    del Train_set['r_f']
    trainX = Train_set.iloc[:,2:].values

    n_features = trainX.shape[1]

    testY = Test_set['r_f'].values
    del Test_set['r_f']
    testX = Test_set.iloc[:,2:].values

    # reshaping data for lstm model
    trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
    testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
    
    # training model
    model = make_model(n_features, layers_num)
    model.fit(trainX, trainY, batch_size=batch_size, epochs=epoch_size, shuffle=False, verbose=0)
    
    # making predictions
    predictY = model.predict(testX)
    
    # saving results
    test_dict[Stock] = {'y_true': testY, 'y_pred': predictY}
    model.save('QBQR trial\\' + Stock + '_model.h5')
    del model
# Out:
# Training model 1 out of 603. Ticker: A
# Training model 2 out of 603. Ticker: AAL
# Training model 3 out of 603. Ticker: AAP
# Training model 4 out of 603. Ticker: AAPL
# Training model 5 out of 603. Ticker: ABBV
# Training model 6 out of 603. Ticker: ABC
# Training model 7 out of 603. Ticker: ABT
# Training model 8 out of 603. Ticker: ACN
# Training model 9 out of 603. Ticker: ADBE
# Training model 10 out of 603. Ticker: ADI
# Training model 11 out of 603. Ticker: ADM
# Training model 12 out of 603. Ticker: ADP
# Training model 13 out of 603. Ticker: ADS
# Training model 14 out of 603. Ticker: ADSK
# Training model 15 out of 603. Ticker: ADT
# Training model 16 out of 603. Ticker: AEE
# Training model 17 out of 603. Ticker: AEP
# Training model 18 out of 603. Ticker: AES
# Training model 19 out of 603. Ticker: AET
# Training model 20 out of 603. Ticker: AFL
# Training model 21 out of 603. Ticker: AGN
# Training model 22 out of 603. Ticker: AIG
# Training model 23 out of 603. Ticker: AIV
# Training model 24 out of 603. Ticker: AIZ
# Training model 25 out of 603. Ticker: AJG
# Training model 26 out of 603. Ticker: AKAM
# Training model 27 out of 603. Ticker: AKS
# Training model 28 out of 603. Ticker: ALB
# Training model 29 out of 603. Ticker: ALK
# Training model 30 out of 603. Ticker: ALL
# Training model 31 out of 603. Ticker: ALLE
# Training model 32 out of 603. Ticker: ALTR
# Training model 33 out of 603. Ticker: ALXN
# Training model 34 out of 603. Ticker: AMAT
# Training model 35 out of 603. Ticker: AMD
# Training model 36 out of 603. Ticker: AME
# Training model 37 out of 603. Ticker: AMG
# Training model 38 out of 603. Ticker: AMGN
# Training model 39 out of 603. Ticker: AMP
# Training model 40 out of 603. Ticker: AMT
# Training model 41 out of 603. Ticker: AMZN
# Training model 42 out of 603. Ticker: AN
# Training model 43 out of 603. Ticker: ANF
# Training model 44 out of 603. Ticker: ANRZQ
# Training model 45 out of 603. Ticker: ANTM
# Training model 46 out of 603. Ticker: AON
# Training model 47 out of 603. Ticker: APA
# Training model 48 out of 603. Ticker: APC
# Training model 49 out of 603. Ticker: APD
# Training model 50 out of 603. Ticker: APH
# Training model 51 out of 603. Ticker: APOL
# Training model 52 out of 603. Ticker: ARNC
# Training model 53 out of 603. Ticker: ATI
# Training model 54 out of 603. Ticker: ATVI
# Training model 55 out of 603. Ticker: AVB
# Training model 56 out of 603. Ticker: AVGO
# Training model 57 out of 603. Ticker: AVP
# Training model 58 out of 603. Ticker: AVY
# Training model 59 out of 603. Ticker: AWK
# Training model 60 out of 603. Ticker: AXP
# Training model 61 out of 603. Ticker: AYE
# Training model 62 out of 603. Ticker: AYI
# Training model 63 out of 603. Ticker: AZO
# Training model 64 out of 603. Ticker: BA
# Training model 65 out of 603. Ticker: BAC
# Training model 66 out of 603. Ticker: BAX
# Training model 67 out of 603. Ticker: BBBY
# Training model 68 out of 603. Ticker: BBT
# Training model 69 out of 603. Ticker: BBY
# Training model 70 out of 603. Ticker: BCR
# Training model 71 out of 603. Ticker: BDX
# Training model 72 out of 603. Ticker: BEAM
# Training model 73 out of 603. Ticker: BEN
# Training model 74 out of 603. Ticker: BHI
# Training model 75 out of 603. Ticker: BIG
# Training model 76 out of 603. Ticker: BIIB
# Training model 77 out of 603. Ticker: BK
# Training model 78 out of 603. Ticker: BLK
# Training model 79 out of 603. Ticker: BLL
# Training model 80 out of 603. Ticker: BMS
# Training model 81 out of 603. Ticker: BMY
# Training model 82 out of 603. Ticker: BNI
# Training model 83 out of 603. Ticker: BRCM
# Training model 84 out of 603. Ticker: BSX
# Training model 85 out of 603. Ticker: BTUUQ
# Training model 86 out of 603. Ticker: BWA
# Training model 87 out of 603. Ticker: BXLT
# Training model 88 out of 603. Ticker: BXP
# Training model 89 out of 603. Ticker: C
# Training model 90 out of 603. Ticker: CA
# Training model 91 out of 603. Ticker: CAG
# Training model 92 out of 603. Ticker: CAH
# Training model 93 out of 603. Ticker: CAM
# Training model 94 out of 603. Ticker: CAT
# Training model 95 out of 603. Ticker: CB
# Training model 96 out of 603. Ticker: CBE
# Training model 97 out of 603. Ticker: CBG
# Training model 98 out of 603. Ticker: CBS
# Training model 99 out of 603. Ticker: CCI
# Training model 100 out of 603. Ticker: CCL
# Training model 101 out of 603. Ticker: CEG
# Training model 102 out of 603. Ticker: CELG
# Training model 103 out of 603. Ticker: CEPH
# Training model 104 out of 603. Ticker: CERN
# Training model 105 out of 603. Ticker: CF
# Training model 106 out of 603. Ticker: CFG
# Training model 107 out of 603. Ticker: CFN
# Training model 108 out of 603. Ticker: CHD
# Training model 109 out of 603. Ticker: CHK
# Training model 110 out of 603. Ticker: CHRW
# Training model 111 out of 603. Ticker: CHTR
# Training model 112 out of 603. Ticker: CI
# Training model 113 out of 603. Ticker: CINF
# Training model 114 out of 603. Ticker: CL
# Training model 115 out of 603. Ticker: CLX
# Training model 116 out of 603. Ticker: CMA
# Training model 117 out of 603. Ticker: CMCSA
# Training model 118 out of 603. Ticker: CMCSK
# Training model 119 out of 603. Ticker: CME
# Training model 120 out of 603. Ticker: CMG
# Training model 121 out of 603. Ticker: CMI
# Training model 122 out of 603. Ticker: CMS
# Training model 123 out of 603. Ticker: CNC
# Training model 124 out of 603. Ticker: CNP
# Training model 125 out of 603. Ticker: CNX
# Training model 126 out of 603. Ticker: COF
# Training model 127 out of 603. Ticker: COG
# Training model 128 out of 603. Ticker: COH
# Training model 129 out of 603. Ticker: COL
# Training model 130 out of 603. Ticker: COO
# Training model 131 out of 603. Ticker: COP
# Training model 132 out of 603. Ticker: COST
# Training model 133 out of 603. Ticker: COTY
# Training model 134 out of 603. Ticker: COV
# Training model 135 out of 603. Ticker: CPB
# Training model 136 out of 603. Ticker: CPGX
# Training model 137 out of 603. Ticker: CRM
# Training model 138 out of 603. Ticker: CSC
# Training model 139 out of 603. Ticker: CSCO
# Training model 140 out of 603. Ticker: CSRA
# Training model 141 out of 603. Ticker: CSX
# Training model 142 out of 603. Ticker: CTAS
# Training model 143 out of 603. Ticker: CTL
# Training model 144 out of 603. Ticker: CTSH
# Training model 145 out of 603. Ticker: CTXS
# Training model 146 out of 603. Ticker: CVC
# Training model 147 out of 603. Ticker: CVH
# Training model 148 out of 603. Ticker: CVS
# Training model 149 out of 603. Ticker: CVX
# Training model 150 out of 603. Ticker: CXO
# Training model 151 out of 603. Ticker: D
# Training model 152 out of 603. Ticker: DAL
# Training model 153 out of 603. Ticker: DD
# Training model 154 out of 603. Ticker: DE
# Training model 155 out of 603. Ticker: DELL
# Training model 156 out of 603. Ticker: DF
# Training model 157 out of 603. Ticker: DFS
# Training model 158 out of 603. Ticker: DG
# Training model 159 out of 603. Ticker: DGX
# Training model 160 out of 603. Ticker: DHI
# Training model 161 out of 603. Ticker: DHR
# Training model 162 out of 603. Ticker: DIS
# Training model 163 out of 603. Ticker: DISCA
# Training model 164 out of 603. Ticker: DISCK
# Training model 165 out of 603. Ticker: DLPH
# Training model 166 out of 603. Ticker: DLR
# Training model 167 out of 603. Ticker: DLTR
# Training model 168 out of 603. Ticker: DNB
# Training model 169 out of 603. Ticker: DNR
# Training model 170 out of 603. Ticker: DO
# Training model 171 out of 603. Ticker: DOV
# Training model 172 out of 603. Ticker: DPS
# Training model 173 out of 603. Ticker: DRI
# Training model 174 out of 603. Ticker: DTE
# Training model 175 out of 603. Ticker: DUK
# Training model 176 out of 603. Ticker: DVA
# Training model 177 out of 603. Ticker: DVN
# Training model 178 out of 603. Ticker: EA
# Training model 179 out of 603. Ticker: EBAY
# Training model 180 out of 603. Ticker: ECL
# Training model 181 out of 603. Ticker: ED
# Training model 182 out of 603. Ticker: EFX
# Training model 183 out of 603. Ticker: EIX
# Training model 184 out of 603. Ticker: EKDKQ
# Training model 185 out of 603. Ticker: EL
# Training model 186 out of 603. Ticker: EMC
# Training model 187 out of 603. Ticker: EMN
# Training model 188 out of 603. Ticker: EMR
# Training model 189 out of 603. Ticker: ENDP
# Training model 190 out of 603. Ticker: EOG
# Training model 191 out of 603. Ticker: EP
# Training model 192 out of 603. Ticker: EQIX
# Training model 193 out of 603. Ticker: EQR
# Training model 194 out of 603. Ticker: EQT
# Training model 195 out of 603. Ticker: ES
# Training model 196 out of 603. Ticker: ESRX
# Training model 197 out of 603. Ticker: ESS
# Training model 198 out of 603. Ticker: ESV
# Training model 199 out of 603. Ticker: ETFC
# Training model 200 out of 603. Ticker: ETN
# Training model 201 out of 603. Ticker: ETR
# Training model 202 out of 603. Ticker: EVHC
# Training model 203 out of 603. Ticker: EW
# Training model 204 out of 603. Ticker: EXC
# Training model 205 out of 603. Ticker: EXPD
# Training model 206 out of 603. Ticker: EXPE
# Training model 207 out of 603. Ticker: EXR
# Training model 208 out of 603. Ticker: F
# Training model 209 out of 603. Ticker: FAST
# Training model 210 out of 603. Ticker: FB
# Training model 211 out of 603. Ticker: FBHS
# Training model 212 out of 603. Ticker: FCX
# Training model 213 out of 603. Ticker: FDO
# Training model 214 out of 603. Ticker: FDX
# Training model 215 out of 603. Ticker: FE
# Training model 216 out of 603. Ticker: FFIV
# Training model 217 out of 603. Ticker: FHN
# Training model 218 out of 603. Ticker: FII
# Training model 219 out of 603. Ticker: FIS
# Training model 220 out of 603. Ticker: FISV
# Training model 221 out of 603. Ticker: FITB
# Training model 222 out of 603. Ticker: FL
# Training model 223 out of 603. Ticker: FLIR
# Training model 224 out of 603. Ticker: FLR
# Training model 225 out of 603. Ticker: FLS
# Training model 226 out of 603. Ticker: FMC
# Training model 227 out of 603. Ticker: FOSL
# Training model 228 out of 603. Ticker: FOX
# Training model 229 out of 603. Ticker: FOXA
# Training model 230 out of 603. Ticker: FRT
# Training model 231 out of 603. Ticker: FRX
# Training model 232 out of 603. Ticker: FSLR
# Training model 233 out of 603. Ticker: FTI
# Training model 234 out of 603. Ticker: FTV
# Training model 235 out of 603. Ticker: GAS
# Training model 236 out of 603. Ticker: GD
# Training model 237 out of 603. Ticker: GE
# Training model 238 out of 603. Ticker: GENZ
# Training model 239 out of 603. Ticker: GGP
# Training model 240 out of 603. Ticker: GHC
# Training model 241 out of 603. Ticker: GILD
# Training model 242 out of 603. Ticker: GIS
# Training model 243 out of 603. Ticker: GLW
# Training model 244 out of 603. Ticker: GM
# Training model 245 out of 603. Ticker: GME
# Training model 246 out of 603. Ticker: GNW
# Training model 247 out of 603. Ticker: GOOG
# Training model 248 out of 603. Ticker: GOOGL
# Training model 249 out of 603. Ticker: GPC
# Training model 250 out of 603. Ticker: GPN
# Training model 251 out of 603. Ticker: GPS
# Training model 252 out of 603. Ticker: GR
# Training model 253 out of 603. Ticker: GRMN
# Training model 254 out of 603. Ticker: GS
# Training model 255 out of 603. Ticker: GT
# Training model 256 out of 603. Ticker: GWW
# Training model 257 out of 603. Ticker: HAL
# Training model 258 out of 603. Ticker: HAR
# Training model 259 out of 603. Ticker: HAS
# Training model 260 out of 603. Ticker: HBAN
# Training model 261 out of 603. Ticker: HBI
# Training model 262 out of 603. Ticker: HCA
# Training model 263 out of 603. Ticker: HCBK
# Training model 264 out of 603. Ticker: HCN
# Training model 265 out of 603. Ticker: HCP
# Training model 266 out of 603. Ticker: HD
# Training model 267 out of 603. Ticker: HES
# Training model 268 out of 603. Ticker: HIG
# Training model 269 out of 603. Ticker: HNZ
# Training model 270 out of 603. Ticker: HOG
# Training model 271 out of 603. Ticker: HOLX
# Training model 272 out of 603. Ticker: HON
# Training model 273 out of 603. Ticker: HOT
# Training model 274 out of 603. Ticker: HP
# Training model 275 out of 603. Ticker: HPE
# Training model 276 out of 603. Ticker: HPQ
# Training model 277 out of 603. Ticker: HRB
# Training model 278 out of 603. Ticker: HRL
# Training model 279 out of 603. Ticker: HRS
# Training model 280 out of 603. Ticker: HSH
# Training model 281 out of 603. Ticker: HSIC
# Training model 282 out of 603. Ticker: HSP
# Training model 283 out of 603. Ticker: HST
# Training model 284 out of 603. Ticker: HSY
# Training model 285 out of 603. Ticker: HUM
# Training model 286 out of 603. Ticker: IBM
# Training model 287 out of 603. Ticker: ICE
# Training model 288 out of 603. Ticker: IFF
# Training model 289 out of 603. Ticker: ILMN
# Training model 290 out of 603. Ticker: INTC
# Training model 291 out of 603. Ticker: INTU
# Training model 292 out of 603. Ticker: IP
# Training model 293 out of 603. Ticker: IPG
# Training model 294 out of 603. Ticker: IR
# Training model 295 out of 603. Ticker: IRM
# Training model 296 out of 603. Ticker: ISRG
# Training model 297 out of 603. Ticker: ITT
# Training model 298 out of 603. Ticker: ITW
# Training model 299 out of 603. Ticker: IVZ
# Training model 300 out of 603. Ticker: JBHT
# Training model 301 out of 603. Ticker: JBL
# Training model 302 out of 603. Ticker: JCI
# Training model 303 out of 603. Ticker: JCP
# Training model 304 out of 603. Ticker: JEC
# Training model 305 out of 603. Ticker: JNJ
# Training model 306 out of 603. Ticker: JNPR
# Training model 307 out of 603. Ticker: JNS
# Training model 308 out of 603. Ticker: JOY
# Training model 309 out of 603. Ticker: JPM
# Training model 310 out of 603. Ticker: JWN
# Training model 311 out of 603. Ticker: K
# Training model 312 out of 603. Ticker: KEY
# Training model 313 out of 603. Ticker: KG
# Training model 314 out of 603. Ticker: KHC
# Training model 315 out of 603. Ticker: KIM
# Training model 316 out of 603. Ticker: KLAC
# Training model 317 out of 603. Ticker: KMB
# Training model 318 out of 603. Ticker: KMI
# Training model 319 out of 603. Ticker: KMX
# Training model 320 out of 603. Ticker: KO
# Training model 321 out of 603. Ticker: KORS
# Training model 322 out of 603. Ticker: KR
# Training model 323 out of 603. Ticker: KSS
# Training model 324 out of 603. Ticker: KSU
# Training model 325 out of 603. Ticker: L
# Training model 326 out of 603. Ticker: LB
# Training model 327 out of 603. Ticker: LDOS
# Training model 328 out of 603. Ticker: LEG
# Training model 329 out of 603. Ticker: LEN
# Training model 330 out of 603. Ticker: LH
# Training model 331 out of 603. Ticker: LKQ
# Training model 332 out of 603. Ticker: LLL
# Training model 333 out of 603. Ticker: LLTC
# Training model 334 out of 603. Ticker: LLY
# Training model 335 out of 603. Ticker: LM
# Training model 336 out of 603. Ticker: LMT
# Training model 337 out of 603. Ticker: LNC
# Training model 338 out of 603. Ticker: LNT
# Training model 339 out of 603. Ticker: LO
# Training model 340 out of 603. Ticker: LOW
# Training model 341 out of 603. Ticker: LRCX
# Training model 342 out of 603. Ticker: LUK
# Training model 343 out of 603. Ticker: LUV
# Training model 344 out of 603. Ticker: LVLT
# Training model 345 out of 603. Ticker: LXK
# Training model 346 out of 603. Ticker: LYB
# Training model 347 out of 603. Ticker: M
# Training model 348 out of 603. Ticker: MA
# Training model 349 out of 603. Ticker: MAA
# Training model 350 out of 603. Ticker: MAC
# Training model 351 out of 603. Ticker: MAR
# Training model 352 out of 603. Ticker: MAS
# Training model 353 out of 603. Ticker: MAT
# Training model 354 out of 603. Ticker: MCD
# Training model 355 out of 603. Ticker: MCHP
# Training model 356 out of 603. Ticker: MCK
# Training model 357 out of 603. Ticker: MCO
# Training model 358 out of 603. Ticker: MDLZ
# Training model 359 out of 603. Ticker: MDP
# Training model 360 out of 603. Ticker: MDT
# Training model 361 out of 603. Ticker: MEE
# Training model 362 out of 603. Ticker: MET
# Training model 363 out of 603. Ticker: MFE
# Training model 364 out of 603. Ticker: MHK
# Training model 365 out of 603. Ticker: MHS
# Training model 366 out of 603. Ticker: MI
# Training model 367 out of 603. Ticker: MJN
# Training model 368 out of 603. Ticker: MKC
# Training model 369 out of 603. Ticker: MLM
# Training model 370 out of 603. Ticker: MMC
# Training model 371 out of 603. Ticker: MMM
# Training model 372 out of 603. Ticker: MNK
# Training model 373 out of 603. Ticker: MNST
# Training model 374 out of 603. Ticker: MO
# Training model 375 out of 603. Ticker: MOLX
# Training model 376 out of 603. Ticker: MON
# Training model 377 out of 603. Ticker: MOS
# Training model 378 out of 603. Ticker: MPC
# Training model 379 out of 603. Ticker: MRK
# Training model 380 out of 603. Ticker: MRO
# Training model 381 out of 603. Ticker: MS
# Training model 382 out of 603. Ticker: MSFT
# Training model 383 out of 603. Ticker: MSI
# Training model 384 out of 603. Ticker: MTB
# Training model 385 out of 603. Ticker: MTD
# Training model 386 out of 603. Ticker: MU
# Training model 387 out of 603. Ticker: MUR
# Training model 388 out of 603. Ticker: MWW
# Training model 389 out of 603. Ticker: MYL
# Training model 390 out of 603. Ticker: NAVI
# Training model 391 out of 603. Ticker: NBL
# Training model 392 out of 603. Ticker: NBR
# Training model 393 out of 603. Ticker: NDAQ
# Training model 394 out of 603. Ticker: NE
# Training model 395 out of 603. Ticker: NEE
# Training model 396 out of 603. Ticker: NEM
# Training model 397 out of 603. Ticker: NFLX
# Training model 398 out of 603. Ticker: NFX
# Training model 399 out of 603. Ticker: NI
# Training model 400 out of 603. Ticker: NKE
# Training model 401 out of 603. Ticker: NLSN
# Training model 402 out of 603. Ticker: NOC
# Training model 403 out of 603. Ticker: NOV
# Training model 404 out of 603. Ticker: NOVL
# Training model 405 out of 603. Ticker: NRG
# Training model 406 out of 603. Ticker: NSC
# Training model 407 out of 603. Ticker: NTAP
# Training model 408 out of 603. Ticker: NTRS
# Training model 409 out of 603. Ticker: NUE
# Training model 410 out of 603. Ticker: NVDA
# Training model 411 out of 603. Ticker: NWL
# Training model 412 out of 603. Ticker: NWS
# Training model 413 out of 603. Ticker: NWSA
# Training model 414 out of 603. Ticker: NYT
# Training model 415 out of 603. Ticker: NYX
# Training model 416 out of 603. Ticker: O
# Training model 417 out of 603. Ticker: ODP
# Training model 418 out of 603. Ticker: OI
# Training model 419 out of 603. Ticker: OKE
# Training model 420 out of 603. Ticker: OMC
# Training model 421 out of 603. Ticker: ORCL
# Training model 422 out of 603. Ticker: ORLY
# Training model 423 out of 603. Ticker: OXY
# Training model 424 out of 603. Ticker: PAYX
# Training model 425 out of 603. Ticker: PBCT
# Training model 426 out of 603. Ticker: PBI
# Training model 427 out of 603. Ticker: PCAR
# Training model 428 out of 603. Ticker: PCG
# Training model 429 out of 603. Ticker: PCL
# Training model 430 out of 603. Ticker: PCLN
# Training model 431 out of 603. Ticker: PCP
# Training model 432 out of 603. Ticker: PDCO
# Training model 433 out of 603. Ticker: PEG
# Training model 434 out of 603. Ticker: PEP
# Training model 435 out of 603. Ticker: PETM
# Training model 436 out of 603. Ticker: PFE
# Training model 437 out of 603. Ticker: PFG
# Training model 438 out of 603. Ticker: PG
# Training model 439 out of 603. Ticker: PGR
# Training model 440 out of 603. Ticker: PH
# Training model 441 out of 603. Ticker: PHM
# Training model 442 out of 603. Ticker: PKI
# Training model 443 out of 603. Ticker: PLD
# Training model 444 out of 603. Ticker: PLL
# Training model 445 out of 603. Ticker: PM
# Training model 446 out of 603. Ticker: PNC
# Training model 447 out of 603. Ticker: PNR
# Training model 448 out of 603. Ticker: PNW
# Training model 449 out of 603. Ticker: POM
# Training model 450 out of 603. Ticker: PPG
# Training model 451 out of 603. Ticker: PPL
# Training model 452 out of 603. Ticker: PRGO
# Training model 453 out of 603. Ticker: PRU
# Training model 454 out of 603. Ticker: PSA
# Training model 455 out of 603. Ticker: PSX
# Training model 456 out of 603. Ticker: PTV
# Training model 457 out of 603. Ticker: PVH
# Training model 458 out of 603. Ticker: PWR
# Training model 459 out of 603. Ticker: PX
# Training model 460 out of 603. Ticker: PXD
# Training model 461 out of 603. Ticker: PYPL
# Training model 462 out of 603. Ticker: QCOM
# Training model 463 out of 603. Ticker: QEP
# Training model 464 out of 603. Ticker: QLGC
# Training model 465 out of 603. Ticker: QRVO
# Training model 466 out of 603. Ticker: R
# Training model 467 out of 603. Ticker: RAI
# Training model 468 out of 603. Ticker: RCL
# Training model 469 out of 603. Ticker: REGN
# Training model 470 out of 603. Ticker: RF
# Training model 471 out of 603. Ticker: RHI
# Training model 472 out of 603. Ticker: RHT
# Training model 473 out of 603. Ticker: RIG
# Training model 474 out of 603. Ticker: RL
# Training model 475 out of 603. Ticker: ROK
# Training model 476 out of 603. Ticker: ROP
# Training model 477 out of 603. Ticker: ROST
# Training model 478 out of 603. Ticker: RRC
# Training model 479 out of 603. Ticker: RRD
# Training model 480 out of 603. Ticker: RSG
# Training model 481 out of 603. Ticker: RSHCQ
# Training model 482 out of 603. Ticker: RTN
# Training model 483 out of 603. Ticker: SBUX
# Training model 484 out of 603. Ticker: SCG
# Training model 485 out of 603. Ticker: SCHW
# Training model 486 out of 603. Ticker: SEE
# Training model 487 out of 603. Ticker: SHLD
# Training model 488 out of 603. Ticker: SHW
# Training model 489 out of 603. Ticker: SIG
# Training model 490 out of 603. Ticker: SII
# Training model 491 out of 603. Ticker: SJM
# Training model 492 out of 603. Ticker: SLB
# Training model 493 out of 603. Ticker: SLG
# Training model 494 out of 603. Ticker: SLM
# Training model 495 out of 603. Ticker: SNA
# Training model 496 out of 603. Ticker: SNDK
# Training model 497 out of 603. Ticker: SNI
# Training model 498 out of 603. Ticker: SO
# Training model 499 out of 603. Ticker: SPG
# Training model 500 out of 603. Ticker: SPGI
# Training model 501 out of 603. Ticker: SPLS
# Training model 502 out of 603. Ticker: SRCL
# Training model 503 out of 603. Ticker: SRE
# Training model 504 out of 603. Ticker: STI
# Training model 505 out of 603. Ticker: STJ
# Training model 506 out of 603. Ticker: STR
# Training model 507 out of 603. Ticker: STT
# Training model 508 out of 603. Ticker: STX
# Training model 509 out of 603. Ticker: STZ
# Training model 510 out of 603. Ticker: SUNEQ
# Training model 511 out of 603. Ticker: SWK
# Training model 512 out of 603. Ticker: SWKS
# Training model 513 out of 603. Ticker: SWN
# Training model 514 out of 603. Ticker: SWY
# Training model 515 out of 603. Ticker: SYF
# Training model 516 out of 603. Ticker: SYK
# Training model 517 out of 603. Ticker: SYMC
# Training model 518 out of 603. Ticker: SYY
# Training model 519 out of 603. Ticker: T
# Training model 520 out of 603. Ticker: TAP
# Training model 521 out of 603. Ticker: TDC
# Training model 522 out of 603. Ticker: TDG
# Training model 523 out of 603. Ticker: TEG
# Training model 524 out of 603. Ticker: TEL
# Training model 525 out of 603. Ticker: TER
# Training model 526 out of 603. Ticker: TGNA
# Training model 527 out of 603. Ticker: TGT
# Training model 528 out of 603. Ticker: THC
# Training model 529 out of 603. Ticker: TIE
# Training model 530 out of 603. Ticker: TIF
# Training model 531 out of 603. Ticker: TJX
# Training model 532 out of 603. Ticker: TLAB
# Training model 533 out of 603. Ticker: TMK
# Training model 534 out of 603. Ticker: TMO
# Training model 535 out of 603. Ticker: TMUS
# Training model 536 out of 603. Ticker: TRIP
# Training model 537 out of 603. Ticker: TROW
# Training model 538 out of 603. Ticker: TRV
# Training model 539 out of 603. Ticker: TSCO
# Training model 540 out of 603. Ticker: TSN
# Training model 541 out of 603. Ticker: TSS
# Training model 542 out of 603. Ticker: TWC
# Training model 543 out of 603. Ticker: TWX
# Training model 544 out of 603. Ticker: TXN
# Training model 545 out of 603. Ticker: TXT
# Training model 546 out of 603. Ticker: UA
# Training model 547 out of 603. Ticker: UAA
# Training model 548 out of 603. Ticker: UAL
# Training model 549 out of 603. Ticker: UDR
# Training model 550 out of 603. Ticker: UHS
# Training model 551 out of 603. Ticker: ULTA
# Training model 552 out of 603. Ticker: UNH
# Training model 553 out of 603. Ticker: UNM
# Training model 554 out of 603. Ticker: UNP
# Training model 555 out of 603. Ticker: UPS
# Training model 556 out of 603. Ticker: URBN
# Training model 557 out of 603. Ticker: URI
# Training model 558 out of 603. Ticker: USB
# Training model 559 out of 603. Ticker: UTX
# Training model 560 out of 603. Ticker: V
# Training model 561 out of 603. Ticker: VAR
# Training model 562 out of 603. Ticker: VFC
# Training model 563 out of 603. Ticker: VIAB
# Training model 564 out of 603. Ticker: VIAV
# Training model 565 out of 603. Ticker: VLO
# Training model 566 out of 603. Ticker: VMC
# Training model 567 out of 603. Ticker: VNO
# Training model 568 out of 603. Ticker: VRSK
# Training model 569 out of 603. Ticker: VRSN
# Training model 570 out of 603. Ticker: VRTX
# Training model 571 out of 603. Ticker: VTR
# Training model 572 out of 603. Ticker: VZ
# Training model 573 out of 603. Ticker: WAT
# Training model 574 out of 603. Ticker: WBA
# Training model 575 out of 603. Ticker: WDC
# Training model 576 out of 603. Ticker: WEC
# Training model 577 out of 603. Ticker: WFC
# Training model 578 out of 603. Ticker: WFM
# Training model 579 out of 603. Ticker: WHR
# Training model 580 out of 603. Ticker: WIN
# Training model 581 out of 603. Ticker: WLTW
# Training model 582 out of 603. Ticker: WM
# Training model 583 out of 603. Ticker: WMB
# Training model 584 out of 603. Ticker: WMT
# Training model 585 out of 603. Ticker: WPX
# Training model 586 out of 603. Ticker: WRK
# Training model 587 out of 603. Ticker: WU
# Training model 588 out of 603. Ticker: WY
# Training model 589 out of 603. Ticker: WYN
# Training model 590 out of 603. Ticker: WYNN
# Training model 591 out of 603. Ticker: X
# Training model 592 out of 603. Ticker: XEC
# Training model 593 out of 603. Ticker: XEL
# Training model 594 out of 603. Ticker: XL
# Training model 595 out of 603. Ticker: XLNX
# Training model 596 out of 603. Ticker: XOM
# Training model 597 out of 603. Ticker: XRAY
# Training model 598 out of 603. Ticker: XTO
# Training model 599 out of 603. Ticker: XYL
# Training model 600 out of 603. Ticker: YUM
# Training model 601 out of 603. Ticker: ZBH
# Training model 602 out of 603. Ticker: ZION
# Training model 603 out of 603. Ticker: ZTS

# %% [markdown]
# ######

# %% [markdown]
# # Combining predicted returns on test dataset

# %%
n_lags = 49
Cut_off_date = '2016-01-01'
y_true = pd.DataFrame()
y_pred = pd.DataFrame()

for row in Sectors.iterrows():
    index = row[0]
    Stock = row[1]['Ticker']
    print ('Processing ' + str(index + 1) + ' out of ' + str(len(Sectors.index)) + '. Ticker: ' + Stock)

    Mask = SPX_Mask[['Date', Stock]]   
    Features = get_features(n_lags, Stock, Mask)
    Test_set = Features[Features['Date'] >= Cut_off_date]  
    
    y_true_add = pd.DataFrame(Test_set['Date_Time'])
    y_true_add[Stock] = test_dict[Stock]['y_true']
    y_true_add.set_index('Date_Time', inplace = True)
    y_true = y_true.merge(y_true_add, left_index=True, right_index=True, how='outer')
    
    y_pred_add = pd.DataFrame(Test_set['Date_Time'])
    y_pred_add[Stock] = test_dict[Stock]['y_pred']
    y_pred_add.set_index('Date_Time', inplace = True)
    y_pred = y_pred.merge(y_pred_add, left_index=True, right_index=True, how='outer')

y_true = y_true.reset_index().groupby('Date_Time').mean()
y_pred = y_pred.reset_index().groupby('Date_Time').mean()
# Out:
# Processing 1 out of 603. Ticker: A
# Processing 2 out of 603. Ticker: AAL
# Processing 3 out of 603. Ticker: AAP
# Processing 4 out of 603. Ticker: AAPL
# Processing 5 out of 603. Ticker: ABBV
# Processing 6 out of 603. Ticker: ABC
# Processing 7 out of 603. Ticker: ABT
# Processing 8 out of 603. Ticker: ACN
# Processing 9 out of 603. Ticker: ADBE
# Processing 10 out of 603. Ticker: ADI
# Processing 11 out of 603. Ticker: ADM
# Processing 12 out of 603. Ticker: ADP
# Processing 13 out of 603. Ticker: ADS
# Processing 14 out of 603. Ticker: ADSK
# Processing 15 out of 603. Ticker: ADT
# Processing 16 out of 603. Ticker: AEE
# Processing 17 out of 603. Ticker: AEP
# Processing 18 out of 603. Ticker: AES
# Processing 19 out of 603. Ticker: AET
# Processing 20 out of 603. Ticker: AFL
# Processing 21 out of 603. Ticker: AGN
# Processing 22 out of 603. Ticker: AIG
# Processing 23 out of 603. Ticker: AIV
# Processing 24 out of 603. Ticker: AIZ
# Processing 25 out of 603. Ticker: AJG
# Processing 26 out of 603. Ticker: AKAM
# Processing 27 out of 603. Ticker: AKS
# Processing 28 out of 603. Ticker: ALB
# Processing 29 out of 603. Ticker: ALK
# Processing 30 out of 603. Ticker: ALL
# Processing 31 out of 603. Ticker: ALLE
# Processing 32 out of 603. Ticker: ALTR
# Processing 33 out of 603. Ticker: ALXN
# Processing 34 out of 603. Ticker: AMAT
# Processing 35 out of 603. Ticker: AMD
# Processing 36 out of 603. Ticker: AME
# Processing 37 out of 603. Ticker: AMG
# Processing 38 out of 603. Ticker: AMGN
# Processing 39 out of 603. Ticker: AMP
# Processing 40 out of 603. Ticker: AMT
# Processing 41 out of 603. Ticker: AMZN
# Processing 42 out of 603. Ticker: AN
# Processing 43 out of 603. Ticker: ANF
# Processing 44 out of 603. Ticker: ANRZQ
# Processing 45 out of 603. Ticker: ANTM
# Processing 46 out of 603. Ticker: AON
# Processing 47 out of 603. Ticker: APA
# Processing 48 out of 603. Ticker: APC
# Processing 49 out of 603. Ticker: APD
# Processing 50 out of 603. Ticker: APH
# Processing 51 out of 603. Ticker: APOL
# Processing 52 out of 603. Ticker: ARNC
# Processing 53 out of 603. Ticker: ATI
# Processing 54 out of 603. Ticker: ATVI
# Processing 55 out of 603. Ticker: AVB
# Processing 56 out of 603. Ticker: AVGO
# Processing 57 out of 603. Ticker: AVP
# Processing 58 out of 603. Ticker: AVY
# Processing 59 out of 603. Ticker: AWK
# Processing 60 out of 603. Ticker: AXP
# Processing 61 out of 603. Ticker: AYE
# Processing 62 out of 603. Ticker: AYI
# Processing 63 out of 603. Ticker: AZO
# Processing 64 out of 603. Ticker: BA
# Processing 65 out of 603. Ticker: BAC
# Processing 66 out of 603. Ticker: BAX
# Processing 67 out of 603. Ticker: BBBY
# Processing 68 out of 603. Ticker: BBT
# Processing 69 out of 603. Ticker: BBY
# Processing 70 out of 603. Ticker: BCR
# Processing 71 out of 603. Ticker: BDX
# Processing 72 out of 603. Ticker: BEAM
# Processing 73 out of 603. Ticker: BEN
# Processing 74 out of 603. Ticker: BHI
# Processing 75 out of 603. Ticker: BIG
# Processing 76 out of 603. Ticker: BIIB
# Processing 77 out of 603. Ticker: BK
# Processing 78 out of 603. Ticker: BLK
# Processing 79 out of 603. Ticker: BLL
# Processing 80 out of 603. Ticker: BMS
# Processing 81 out of 603. Ticker: BMY
# Processing 82 out of 603. Ticker: BNI
# Processing 83 out of 603. Ticker: BRCM
# Processing 84 out of 603. Ticker: BSX
# Processing 85 out of 603. Ticker: BTUUQ
# Processing 86 out of 603. Ticker: BWA
# Processing 87 out of 603. Ticker: BXLT
# Processing 88 out of 603. Ticker: BXP
# Processing 89 out of 603. Ticker: C
# Processing 90 out of 603. Ticker: CA
# Processing 91 out of 603. Ticker: CAG
# Processing 92 out of 603. Ticker: CAH
# Processing 93 out of 603. Ticker: CAM
# Processing 94 out of 603. Ticker: CAT
# Processing 95 out of 603. Ticker: CB
# Processing 96 out of 603. Ticker: CBE
# Processing 97 out of 603. Ticker: CBG
# Processing 98 out of 603. Ticker: CBS
# Processing 99 out of 603. Ticker: CCI
# Processing 100 out of 603. Ticker: CCL
# Processing 101 out of 603. Ticker: CEG
# Processing 102 out of 603. Ticker: CELG
# Processing 103 out of 603. Ticker: CEPH
# Processing 104 out of 603. Ticker: CERN
# Processing 105 out of 603. Ticker: CF
# Processing 106 out of 603. Ticker: CFG
# Processing 107 out of 603. Ticker: CFN
# Processing 108 out of 603. Ticker: CHD
# Processing 109 out of 603. Ticker: CHK
# Processing 110 out of 603. Ticker: CHRW
# Processing 111 out of 603. Ticker: CHTR
# Processing 112 out of 603. Ticker: CI
# Processing 113 out of 603. Ticker: CINF
# Processing 114 out of 603. Ticker: CL
# Processing 115 out of 603. Ticker: CLX
# Processing 116 out of 603. Ticker: CMA
# Processing 117 out of 603. Ticker: CMCSA
# Processing 118 out of 603. Ticker: CMCSK
# Processing 119 out of 603. Ticker: CME
# Processing 120 out of 603. Ticker: CMG
# Processing 121 out of 603. Ticker: CMI
# Processing 122 out of 603. Ticker: CMS
# Processing 123 out of 603. Ticker: CNC
# Processing 124 out of 603. Ticker: CNP
# Processing 125 out of 603. Ticker: CNX
# Processing 126 out of 603. Ticker: COF
# Processing 127 out of 603. Ticker: COG
# Processing 128 out of 603. Ticker: COH
# Processing 129 out of 603. Ticker: COL
# Processing 130 out of 603. Ticker: COO
# Processing 131 out of 603. Ticker: COP
# Processing 132 out of 603. Ticker: COST
# Processing 133 out of 603. Ticker: COTY
# Processing 134 out of 603. Ticker: COV
# Processing 135 out of 603. Ticker: CPB
# Processing 136 out of 603. Ticker: CPGX
# Processing 137 out of 603. Ticker: CRM
# Processing 138 out of 603. Ticker: CSC
# Processing 139 out of 603. Ticker: CSCO
# Processing 140 out of 603. Ticker: CSRA
# Processing 141 out of 603. Ticker: CSX
# Processing 142 out of 603. Ticker: CTAS
# Processing 143 out of 603. Ticker: CTL
# Processing 144 out of 603. Ticker: CTSH
# Processing 145 out of 603. Ticker: CTXS
# Processing 146 out of 603. Ticker: CVC
# Processing 147 out of 603. Ticker: CVH
# Processing 148 out of 603. Ticker: CVS
# Processing 149 out of 603. Ticker: CVX
# Processing 150 out of 603. Ticker: CXO
# Processing 151 out of 603. Ticker: D
# Processing 152 out of 603. Ticker: DAL
# Processing 153 out of 603. Ticker: DD
# Processing 154 out of 603. Ticker: DE
# Processing 155 out of 603. Ticker: DELL
# Processing 156 out of 603. Ticker: DF
# Processing 157 out of 603. Ticker: DFS
# Processing 158 out of 603. Ticker: DG
# Processing 159 out of 603. Ticker: DGX
# Processing 160 out of 603. Ticker: DHI
# Processing 161 out of 603. Ticker: DHR
# Processing 162 out of 603. Ticker: DIS
# Processing 163 out of 603. Ticker: DISCA
# Processing 164 out of 603. Ticker: DISCK
# Processing 165 out of 603. Ticker: DLPH
# Processing 166 out of 603. Ticker: DLR
# Processing 167 out of 603. Ticker: DLTR
# Processing 168 out of 603. Ticker: DNB
# Processing 169 out of 603. Ticker: DNR
# Processing 170 out of 603. Ticker: DO
# Processing 171 out of 603. Ticker: DOV
# Processing 172 out of 603. Ticker: DPS
# Processing 173 out of 603. Ticker: DRI
# Processing 174 out of 603. Ticker: DTE
# Processing 175 out of 603. Ticker: DUK
# Processing 176 out of 603. Ticker: DVA
# Processing 177 out of 603. Ticker: DVN
# Processing 178 out of 603. Ticker: EA
# Processing 179 out of 603. Ticker: EBAY
# Processing 180 out of 603. Ticker: ECL
# Processing 181 out of 603. Ticker: ED
# Processing 182 out of 603. Ticker: EFX
# Processing 183 out of 603. Ticker: EIX
# Processing 184 out of 603. Ticker: EKDKQ
# Processing 185 out of 603. Ticker: EL
# Processing 186 out of 603. Ticker: EMC
# Processing 187 out of 603. Ticker: EMN
# Processing 188 out of 603. Ticker: EMR
# Processing 189 out of 603. Ticker: ENDP
# Processing 190 out of 603. Ticker: EOG
# Processing 191 out of 603. Ticker: EP
# Processing 192 out of 603. Ticker: EQIX
# Processing 193 out of 603. Ticker: EQR
# Processing 194 out of 603. Ticker: EQT
# Processing 195 out of 603. Ticker: ES
# Processing 196 out of 603. Ticker: ESRX
# Processing 197 out of 603. Ticker: ESS
# Processing 198 out of 603. Ticker: ESV
# Processing 199 out of 603. Ticker: ETFC
# Processing 200 out of 603. Ticker: ETN
# Processing 201 out of 603. Ticker: ETR
# Processing 202 out of 603. Ticker: EVHC
# Processing 203 out of 603. Ticker: EW
# Processing 204 out of 603. Ticker: EXC
# Processing 205 out of 603. Ticker: EXPD
# Processing 206 out of 603. Ticker: EXPE
# Processing 207 out of 603. Ticker: EXR
# Processing 208 out of 603. Ticker: F
# Processing 209 out of 603. Ticker: FAST
# Processing 210 out of 603. Ticker: FB
# Processing 211 out of 603. Ticker: FBHS
# Processing 212 out of 603. Ticker: FCX
# Processing 213 out of 603. Ticker: FDO
# Processing 214 out of 603. Ticker: FDX
# Processing 215 out of 603. Ticker: FE
# Processing 216 out of 603. Ticker: FFIV
# Processing 217 out of 603. Ticker: FHN
# Processing 218 out of 603. Ticker: FII
# Processing 219 out of 603. Ticker: FIS
# Processing 220 out of 603. Ticker: FISV
# Processing 221 out of 603. Ticker: FITB
# Processing 222 out of 603. Ticker: FL
# Processing 223 out of 603. Ticker: FLIR
# Processing 224 out of 603. Ticker: FLR
# Processing 225 out of 603. Ticker: FLS
# Processing 226 out of 603. Ticker: FMC
# Processing 227 out of 603. Ticker: FOSL
# Processing 228 out of 603. Ticker: FOX
# Processing 229 out of 603. Ticker: FOXA
# Processing 230 out of 603. Ticker: FRT
# Processing 231 out of 603. Ticker: FRX
# Processing 232 out of 603. Ticker: FSLR
# Processing 233 out of 603. Ticker: FTI
# Processing 234 out of 603. Ticker: FTV
# Processing 235 out of 603. Ticker: GAS
# Processing 236 out of 603. Ticker: GD
# Processing 237 out of 603. Ticker: GE
# Processing 238 out of 603. Ticker: GENZ
# Processing 239 out of 603. Ticker: GGP
# Processing 240 out of 603. Ticker: GHC
# Processing 241 out of 603. Ticker: GILD
# Processing 242 out of 603. Ticker: GIS
# Processing 243 out of 603. Ticker: GLW
# Processing 244 out of 603. Ticker: GM
# Processing 245 out of 603. Ticker: GME
# Processing 246 out of 603. Ticker: GNW
# Processing 247 out of 603. Ticker: GOOG
# Processing 248 out of 603. Ticker: GOOGL
# Processing 249 out of 603. Ticker: GPC
# Processing 250 out of 603. Ticker: GPN
# Processing 251 out of 603. Ticker: GPS
# Processing 252 out of 603. Ticker: GR
# Processing 253 out of 603. Ticker: GRMN
# Processing 254 out of 603. Ticker: GS
# Processing 255 out of 603. Ticker: GT
# Processing 256 out of 603. Ticker: GWW
# Processing 257 out of 603. Ticker: HAL
# Processing 258 out of 603. Ticker: HAR
# Processing 259 out of 603. Ticker: HAS
# Processing 260 out of 603. Ticker: HBAN
# Processing 261 out of 603. Ticker: HBI
# Processing 262 out of 603. Ticker: HCA
# Processing 263 out of 603. Ticker: HCBK
# Processing 264 out of 603. Ticker: HCN
# Processing 265 out of 603. Ticker: HCP
# Processing 266 out of 603. Ticker: HD
# Processing 267 out of 603. Ticker: HES
# Processing 268 out of 603. Ticker: HIG
# Processing 269 out of 603. Ticker: HNZ
# Processing 270 out of 603. Ticker: HOG
# Processing 271 out of 603. Ticker: HOLX
# Processing 272 out of 603. Ticker: HON
# Processing 273 out of 603. Ticker: HOT
# Processing 274 out of 603. Ticker: HP
# Processing 275 out of 603. Ticker: HPE
# Processing 276 out of 603. Ticker: HPQ
# Processing 277 out of 603. Ticker: HRB
# Processing 278 out of 603. Ticker: HRL
# Processing 279 out of 603. Ticker: HRS
# Processing 280 out of 603. Ticker: HSH
# Processing 281 out of 603. Ticker: HSIC
# Processing 282 out of 603. Ticker: HSP
# Processing 283 out of 603. Ticker: HST
# Processing 284 out of 603. Ticker: HSY
# Processing 285 out of 603. Ticker: HUM
# Processing 286 out of 603. Ticker: IBM
# Processing 287 out of 603. Ticker: ICE
# Processing 288 out of 603. Ticker: IFF
# Processing 289 out of 603. Ticker: ILMN
# Processing 290 out of 603. Ticker: INTC
# Processing 291 out of 603. Ticker: INTU
# Processing 292 out of 603. Ticker: IP
# Processing 293 out of 603. Ticker: IPG
# Processing 294 out of 603. Ticker: IR
# Processing 295 out of 603. Ticker: IRM
# Processing 296 out of 603. Ticker: ISRG
# Processing 297 out of 603. Ticker: ITT
# Processing 298 out of 603. Ticker: ITW
# Processing 299 out of 603. Ticker: IVZ
# Processing 300 out of 603. Ticker: JBHT
# Processing 301 out of 603. Ticker: JBL
# Processing 302 out of 603. Ticker: JCI
# Processing 303 out of 603. Ticker: JCP
# Processing 304 out of 603. Ticker: JEC
# Processing 305 out of 603. Ticker: JNJ
# Processing 306 out of 603. Ticker: JNPR
# Processing 307 out of 603. Ticker: JNS
# Processing 308 out of 603. Ticker: JOY
# Processing 309 out of 603. Ticker: JPM
# Processing 310 out of 603. Ticker: JWN
# Processing 311 out of 603. Ticker: K
# Processing 312 out of 603. Ticker: KEY
# Processing 313 out of 603. Ticker: KG
# Processing 314 out of 603. Ticker: KHC
# Processing 315 out of 603. Ticker: KIM
# Processing 316 out of 603. Ticker: KLAC
# Processing 317 out of 603. Ticker: KMB
# Processing 318 out of 603. Ticker: KMI
# Processing 319 out of 603. Ticker: KMX
# Processing 320 out of 603. Ticker: KO
# Processing 321 out of 603. Ticker: KORS
# Processing 322 out of 603. Ticker: KR
# Processing 323 out of 603. Ticker: KSS
# Processing 324 out of 603. Ticker: KSU
# Processing 325 out of 603. Ticker: L
# Processing 326 out of 603. Ticker: LB
# Processing 327 out of 603. Ticker: LDOS
# Processing 328 out of 603. Ticker: LEG
# Processing 329 out of 603. Ticker: LEN
# Processing 330 out of 603. Ticker: LH
# Processing 331 out of 603. Ticker: LKQ
# Processing 332 out of 603. Ticker: LLL
# Processing 333 out of 603. Ticker: LLTC
# Processing 334 out of 603. Ticker: LLY
# Processing 335 out of 603. Ticker: LM
# Processing 336 out of 603. Ticker: LMT
# Processing 337 out of 603. Ticker: LNC
# Processing 338 out of 603. Ticker: LNT
# Processing 339 out of 603. Ticker: LO
# Processing 340 out of 603. Ticker: LOW
# Processing 341 out of 603. Ticker: LRCX
# Processing 342 out of 603. Ticker: LUK
# Processing 343 out of 603. Ticker: LUV
# Processing 344 out of 603. Ticker: LVLT
# Processing 345 out of 603. Ticker: LXK
# Processing 346 out of 603. Ticker: LYB
# Processing 347 out of 603. Ticker: M
# Processing 348 out of 603. Ticker: MA
# Processing 349 out of 603. Ticker: MAA
# Processing 350 out of 603. Ticker: MAC
# Processing 351 out of 603. Ticker: MAR
# Processing 352 out of 603. Ticker: MAS
# Processing 353 out of 603. Ticker: MAT
# Processing 354 out of 603. Ticker: MCD
# Processing 355 out of 603. Ticker: MCHP
# Processing 356 out of 603. Ticker: MCK
# Processing 357 out of 603. Ticker: MCO
# Processing 358 out of 603. Ticker: MDLZ
# Processing 359 out of 603. Ticker: MDP
# Processing 360 out of 603. Ticker: MDT
# Processing 361 out of 603. Ticker: MEE
# Processing 362 out of 603. Ticker: MET
# Processing 363 out of 603. Ticker: MFE
# Processing 364 out of 603. Ticker: MHK
# Processing 365 out of 603. Ticker: MHS
# Processing 366 out of 603. Ticker: MI
# Processing 367 out of 603. Ticker: MJN
# Processing 368 out of 603. Ticker: MKC
# Processing 369 out of 603. Ticker: MLM
# Processing 370 out of 603. Ticker: MMC
# Processing 371 out of 603. Ticker: MMM
# Processing 372 out of 603. Ticker: MNK
# Processing 373 out of 603. Ticker: MNST
# Processing 374 out of 603. Ticker: MO
# Processing 375 out of 603. Ticker: MOLX
# Processing 376 out of 603. Ticker: MON
# Processing 377 out of 603. Ticker: MOS
# Processing 378 out of 603. Ticker: MPC
# Processing 379 out of 603. Ticker: MRK
# Processing 380 out of 603. Ticker: MRO
# Processing 381 out of 603. Ticker: MS
# Processing 382 out of 603. Ticker: MSFT
# Processing 383 out of 603. Ticker: MSI
# Processing 384 out of 603. Ticker: MTB
# Processing 385 out of 603. Ticker: MTD
# Processing 386 out of 603. Ticker: MU
# Processing 387 out of 603. Ticker: MUR
# Processing 388 out of 603. Ticker: MWW
# Processing 389 out of 603. Ticker: MYL
# Processing 390 out of 603. Ticker: NAVI
# Processing 391 out of 603. Ticker: NBL
# Processing 392 out of 603. Ticker: NBR
# Processing 393 out of 603. Ticker: NDAQ
# Processing 394 out of 603. Ticker: NE
# Processing 395 out of 603. Ticker: NEE
# Processing 396 out of 603. Ticker: NEM
# Processing 397 out of 603. Ticker: NFLX
# Processing 398 out of 603. Ticker: NFX
# Processing 399 out of 603. Ticker: NI
# Processing 400 out of 603. Ticker: NKE
# Processing 401 out of 603. Ticker: NLSN
# Processing 402 out of 603. Ticker: NOC
# Processing 403 out of 603. Ticker: NOV
# Processing 404 out of 603. Ticker: NOVL
# Processing 405 out of 603. Ticker: NRG
# Processing 406 out of 603. Ticker: NSC
# Processing 407 out of 603. Ticker: NTAP
# Processing 408 out of 603. Ticker: NTRS
# Processing 409 out of 603. Ticker: NUE
# Processing 410 out of 603. Ticker: NVDA
# Processing 411 out of 603. Ticker: NWL
# Processing 412 out of 603. Ticker: NWS
# Processing 413 out of 603. Ticker: NWSA
# Processing 414 out of 603. Ticker: NYT
# Processing 415 out of 603. Ticker: NYX
# Processing 416 out of 603. Ticker: O
# Processing 417 out of 603. Ticker: ODP
# Processing 418 out of 603. Ticker: OI
# Processing 419 out of 603. Ticker: OKE
# Processing 420 out of 603. Ticker: OMC
# Processing 421 out of 603. Ticker: ORCL
# Processing 422 out of 603. Ticker: ORLY
# Processing 423 out of 603. Ticker: OXY
# Processing 424 out of 603. Ticker: PAYX
# Processing 425 out of 603. Ticker: PBCT
# Processing 426 out of 603. Ticker: PBI
# Processing 427 out of 603. Ticker: PCAR
# Processing 428 out of 603. Ticker: PCG
# Processing 429 out of 603. Ticker: PCL
# Processing 430 out of 603. Ticker: PCLN
# Processing 431 out of 603. Ticker: PCP
# Processing 432 out of 603. Ticker: PDCO
# Processing 433 out of 603. Ticker: PEG
# Processing 434 out of 603. Ticker: PEP
# Processing 435 out of 603. Ticker: PETM
# Processing 436 out of 603. Ticker: PFE
# Processing 437 out of 603. Ticker: PFG
# Processing 438 out of 603. Ticker: PG
# Processing 439 out of 603. Ticker: PGR
# Processing 440 out of 603. Ticker: PH
# Processing 441 out of 603. Ticker: PHM
# Processing 442 out of 603. Ticker: PKI
# Processing 443 out of 603. Ticker: PLD
# Processing 444 out of 603. Ticker: PLL
# Processing 445 out of 603. Ticker: PM
# Processing 446 out of 603. Ticker: PNC
# Processing 447 out of 603. Ticker: PNR
# Processing 448 out of 603. Ticker: PNW
# Processing 449 out of 603. Ticker: POM
# Processing 450 out of 603. Ticker: PPG
# Processing 451 out of 603. Ticker: PPL
# Processing 452 out of 603. Ticker: PRGO
# Processing 453 out of 603. Ticker: PRU
# Processing 454 out of 603. Ticker: PSA
# Processing 455 out of 603. Ticker: PSX
# Processing 456 out of 603. Ticker: PTV
# Processing 457 out of 603. Ticker: PVH
# Processing 458 out of 603. Ticker: PWR
# Processing 459 out of 603. Ticker: PX
# Processing 460 out of 603. Ticker: PXD
# Processing 461 out of 603. Ticker: PYPL
# Processing 462 out of 603. Ticker: QCOM
# Processing 463 out of 603. Ticker: QEP
# Processing 464 out of 603. Ticker: QLGC
# Processing 465 out of 603. Ticker: QRVO
# Processing 466 out of 603. Ticker: R
# Processing 467 out of 603. Ticker: RAI
# Processing 468 out of 603. Ticker: RCL
# Processing 469 out of 603. Ticker: REGN
# Processing 470 out of 603. Ticker: RF
# Processing 471 out of 603. Ticker: RHI
# Processing 472 out of 603. Ticker: RHT
# Processing 473 out of 603. Ticker: RIG
# Processing 474 out of 603. Ticker: RL
# Processing 475 out of 603. Ticker: ROK
# Processing 476 out of 603. Ticker: ROP
# Processing 477 out of 603. Ticker: ROST
# Processing 478 out of 603. Ticker: RRC
# Processing 479 out of 603. Ticker: RRD
# Processing 480 out of 603. Ticker: RSG
# Processing 481 out of 603. Ticker: RSHCQ
# Processing 482 out of 603. Ticker: RTN
# Processing 483 out of 603. Ticker: SBUX
# Processing 484 out of 603. Ticker: SCG
# Processing 485 out of 603. Ticker: SCHW
# Processing 486 out of 603. Ticker: SEE
# Processing 487 out of 603. Ticker: SHLD
# Processing 488 out of 603. Ticker: SHW
# Processing 489 out of 603. Ticker: SIG
# Processing 490 out of 603. Ticker: SII
# Processing 491 out of 603. Ticker: SJM
# Processing 492 out of 603. Ticker: SLB
# Processing 493 out of 603. Ticker: SLG
# Processing 494 out of 603. Ticker: SLM
# Processing 495 out of 603. Ticker: SNA
# Processing 496 out of 603. Ticker: SNDK
# Processing 497 out of 603. Ticker: SNI
# Processing 498 out of 603. Ticker: SO
# Processing 499 out of 603. Ticker: SPG
# Processing 500 out of 603. Ticker: SPGI
# Processing 501 out of 603. Ticker: SPLS
# Processing 502 out of 603. Ticker: SRCL
# Processing 503 out of 603. Ticker: SRE
# Processing 504 out of 603. Ticker: STI
# Processing 505 out of 603. Ticker: STJ
# Processing 506 out of 603. Ticker: STR
# Processing 507 out of 603. Ticker: STT
# Processing 508 out of 603. Ticker: STX
# Processing 509 out of 603. Ticker: STZ
# Processing 510 out of 603. Ticker: SUNEQ
# Processing 511 out of 603. Ticker: SWK
# Processing 512 out of 603. Ticker: SWKS
# Processing 513 out of 603. Ticker: SWN
# Processing 514 out of 603. Ticker: SWY
# Processing 515 out of 603. Ticker: SYF
# Processing 516 out of 603. Ticker: SYK
# Processing 517 out of 603. Ticker: SYMC
# Processing 518 out of 603. Ticker: SYY
# Processing 519 out of 603. Ticker: T
# Processing 520 out of 603. Ticker: TAP
# Processing 521 out of 603. Ticker: TDC
# Processing 522 out of 603. Ticker: TDG
# Processing 523 out of 603. Ticker: TEG
# Processing 524 out of 603. Ticker: TEL
# Processing 525 out of 603. Ticker: TER
# Processing 526 out of 603. Ticker: TGNA
# Processing 527 out of 603. Ticker: TGT
# Processing 528 out of 603. Ticker: THC
# Processing 529 out of 603. Ticker: TIE
# Processing 530 out of 603. Ticker: TIF
# Processing 531 out of 603. Ticker: TJX
# Processing 532 out of 603. Ticker: TLAB
# Processing 533 out of 603. Ticker: TMK
# Processing 534 out of 603. Ticker: TMO
# Processing 535 out of 603. Ticker: TMUS
# Processing 536 out of 603. Ticker: TRIP
# Processing 537 out of 603. Ticker: TROW
# Processing 538 out of 603. Ticker: TRV
# Processing 539 out of 603. Ticker: TSCO
# Processing 540 out of 603. Ticker: TSN
# Processing 541 out of 603. Ticker: TSS
# Processing 542 out of 603. Ticker: TWC
# Processing 543 out of 603. Ticker: TWX
# Processing 544 out of 603. Ticker: TXN
# Processing 545 out of 603. Ticker: TXT
# Processing 546 out of 603. Ticker: UA
# Processing 547 out of 603. Ticker: UAA
# Processing 548 out of 603. Ticker: UAL
# Processing 549 out of 603. Ticker: UDR
# Processing 550 out of 603. Ticker: UHS
# Processing 551 out of 603. Ticker: ULTA
# Processing 552 out of 603. Ticker: UNH
# Processing 553 out of 603. Ticker: UNM
# Processing 554 out of 603. Ticker: UNP
# Processing 555 out of 603. Ticker: UPS
# Processing 556 out of 603. Ticker: URBN
# Processing 557 out of 603. Ticker: URI
# Processing 558 out of 603. Ticker: USB
# Processing 559 out of 603. Ticker: UTX
# Processing 560 out of 603. Ticker: V
# Processing 561 out of 603. Ticker: VAR
# Processing 562 out of 603. Ticker: VFC
# Processing 563 out of 603. Ticker: VIAB
# Processing 564 out of 603. Ticker: VIAV
# Processing 565 out of 603. Ticker: VLO
# Processing 566 out of 603. Ticker: VMC
# Processing 567 out of 603. Ticker: VNO
# Processing 568 out of 603. Ticker: VRSK
# Processing 569 out of 603. Ticker: VRSN
# Processing 570 out of 603. Ticker: VRTX
# Processing 571 out of 603. Ticker: VTR
# Processing 572 out of 603. Ticker: VZ
# Processing 573 out of 603. Ticker: WAT
# Processing 574 out of 603. Ticker: WBA
# Processing 575 out of 603. Ticker: WDC
# Processing 576 out of 603. Ticker: WEC
# Processing 577 out of 603. Ticker: WFC
# Processing 578 out of 603. Ticker: WFM
# Processing 579 out of 603. Ticker: WHR
# Processing 580 out of 603. Ticker: WIN
# Processing 581 out of 603. Ticker: WLTW
# Processing 582 out of 603. Ticker: WM
# Processing 583 out of 603. Ticker: WMB
# Processing 584 out of 603. Ticker: WMT
# Processing 585 out of 603. Ticker: WPX
# Processing 586 out of 603. Ticker: WRK
# Processing 587 out of 603. Ticker: WU
# Processing 588 out of 603. Ticker: WY
# Processing 589 out of 603. Ticker: WYN
# Processing 590 out of 603. Ticker: WYNN
# Processing 591 out of 603. Ticker: X
# Processing 592 out of 603. Ticker: XEC
# Processing 593 out of 603. Ticker: XEL
# Processing 594 out of 603. Ticker: XL
# Processing 595 out of 603. Ticker: XLNX
# Processing 596 out of 603. Ticker: XOM
# Processing 597 out of 603. Ticker: XRAY
# Processing 598 out of 603. Ticker: XTO
# Processing 599 out of 603. Ticker: XYL
# Processing 600 out of 603. Ticker: YUM
# Processing 601 out of 603. Ticker: ZBH
# Processing 602 out of 603. Ticker: ZION
# Processing 603 out of 603. Ticker: ZTS

# %% [markdown]
# ######

# %% [markdown]
# # Structuring stock portfolio for each period based on predicted returns

# %%
Sector_set = list(set(Sectors['INDUSTRY_SECTOR']))
Portfolio = dict()

index_prev = y_pred.index[0]
Portfolio[index_prev] = []
for Sector in Sector_set:
    Sector_stocks = list(Sectors[Sectors['INDUSTRY_SECTOR'] == Sector]['Ticker'])
    Portfolio[y_pred.index[0]].append(y_pred.iloc[0][Sector_stocks].idxmax())

for index in y_true.index[1:]:
    Portfolio[index] = []
    for sector_index in range(len(Sector_set)):
        
        Sector_stocks = list(Sectors[Sectors['INDUSTRY_SECTOR'] == Sector_set[sector_index]]['Ticker'])
        Sector_Best = y_pred.loc[index][Sector_stocks].idxmax()
        Sector_Prev = Portfolio[index_prev][sector_index]
        
        if ((str(Sector_Best) != 'nan') and (
            (1-transaction_cost)*(1+y_pred.loc[index][Sector_Best]) > (1+y_pred.loc[index][Sector_Prev])*(1+safety_margin))):
            Portfolio[index].append(Sector_Best)
        else:
            Portfolio[index].append(Sector_Prev)

# %% [markdown]
# ######

# %% [markdown]
# # Calculating returns on backtest data set (01/01/2016 - 12/31/2016)

# %%
portfolio_value = {}
index_prev = y_true.index[0]
for sector_index in range(len(Sector_set)):
    portfolio_value[Sector_set[sector_index]] = 1/len(Sector_set) * (
        1 + y_true.loc[index_prev][Portfolio[index_prev][sector_index]])

index_returns = [y_true.loc[index_prev].fillna(0).mean()]
portfolio_values = [1, pd.Series(portfolio_value).sum()]
    
for index in y_true.index[1:]:
    index_returns.append(y_true.loc[index].fillna(0).mean())
    
    for sector_index in range(len(Sector_set)):
        if str(y_true.loc[index][Portfolio[index][sector_index]]) != 'nan':
            portfolio_value[Sector_set[sector_index]] *= (1 + y_true.loc[index][Portfolio[index][sector_index]])
            
            if (Portfolio[index][sector_index] != Portfolio[index_prev][sector_index]):
                portfolio_value[Sector_set[sector_index]] *= (1 - transaction_cost)
    
    portfolio_values.append(pd.Series(portfolio_value).sum())
    index_prev = index

index_returns = pd.Series(index_returns)
portfolio_returns = (pd.Series(portfolio_values)/pd.Series(portfolio_values).shift(1)-1).dropna()

# %% [markdown]
# ######

# %% [markdown]
# # Reporting results of backtesting

# %%
portfolio_total_return = np.prod(1+portfolio_returns)-1
index_total_return = np.prod(1+index_returns)-1

portfolio_std = np.std(portfolio_returns)*np.sqrt(len(portfolio_returns))
index_std = np.std(index_returns)*np.sqrt(len(index_returns))

portfolio_sharpe_ratio = (portfolio_total_return - risk_free)/portfolio_std
index_sharpe_ratio = (index_total_return - risk_free)/index_std

# %%
print('Return of the actively managed portfolio ', round(100*portfolio_total_return,1), '%')
print('Return of the index ', round(100*index_total_return,1), '%')
# Out:
# Return of the actively managed portfolio  10.4 %
# Return of the index  8.9 %

# %%
print('Sharpe ratio of the actively managed portfolio ', round(portfolio_sharpe_ratio,2))
print('Sharpe ratio of the index ', round(index_sharpe_ratio,2))
# Out:
# Sharpe ratio of the actively managed portfolio  0.62
# Sharpe ratio of the index  0.77

# %% [markdown]
# ######
